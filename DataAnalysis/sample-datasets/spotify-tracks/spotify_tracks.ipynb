# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
spotify_df=pd.read_csv("spotify_tracks.csv")
spotify_df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
unique_artist_tracks=spotify_df.value_counts(["artists","track_id"])
unique_artist_tracks
# Out:
# artists                          track_id
# Badfinger                        6S3JlDAGk3uu3NtZbPnuhS    9
# Derek & The Dominos              2Ey6v4Sekh3Z0RUSISRosD    8
#                                  2kkvB3RNRzwjFdGhaUA0tz    8
# Prateek Kuhad                    08kTa3SL9sV6Iy8KLKtGql    7
# Fear, and Loathing in Las Vegas  1Gqpa08T7eBAvPQj9O9L2Q    7
#                                                           ..
# 高爾宣 OSN                          0q1FMCm6hZhyPomad3LQES    1
#                                  1ggo5EkgQKtOcrYlJ0mEZS    1
#                                  1rjUBUTswCkN8DIBxkgjJs    1
#                                  2DwsuwDtMtZykInr8cFo1j    1
# "Puppy Dog Pals" Cast            5qtlopq4SnnvVeiQVt3M0n    1
# Name: count, Length: 89740, dtype: int64

# %%
spotify_df.value_counts("artists").sort_values(ascending=False)
# Out:
# artists
# The Beatles               279
# George Jones              271
# Stevie Wonder             236
# Linkin Park               224
# Ella Fitzgerald           222
#                          ...
# 高爾宣 OSN;李浩瑋 Howard Lee      1
# 高爾宣 OSN;sunkis              1
# 高爾宣 OSN;Vicky Chen          1
# 高木さん(CV:高橋李依)               1
# 風格童星組合                      1
# Name: count, Length: 31437, dtype: int64

# %%
spotify_df["duration_min"]=spotify_df["duration_ms"]/(1000*60)
spotify_df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
plt.figure(figsize=(10,10))
sns.histplot(data=spotify_df,x="duration_min",bins=100,binrange=(0,20))
plt.show()

# %%
spotify_df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
print(f"Avg popularity: {spotify_df["popularity"].mean()}")
# Out:
# Avg popularity: 33.2385350877193

# %%
plt.figure(figsize=(10,10))
sns.histplot(data=spotify_df,x="popularity")
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=spotify_df.head(1000),x="danceability",y="energy")
plt.show()

# %%
most_popular_ten=spotify_df[["popularity","track_name","artists","tempo"]].sort_values(by="popularity",ascending=False).head(10)
most_popular_ten
# Out:
#        popularity                             track_name  \
# 81051         100              Unholy (feat. Kim Petras)
# 20001         100              Unholy (feat. Kim Petras)
# 51664          99  Quevedo: Bzrp Music Sessions, Vol. 52
# 89411          98                             La Bachata
# 30003          98                        I'm Good (Blue)
# 20008          98                        I'm Good (Blue)
# 81210          98                        I'm Good (Blue)
# 88410          98                             La Bachata
# 67356          98                             La Bachata
# 68303          98                             La Bachata
#
#                        artists    tempo
# 81051     Sam Smith;Kim Petras  131.121
# 20001     Sam Smith;Kim Petras  131.121
# 51664         Bizarrap;Quevedo  128.033
# 89411            Manuel Turizo  124.980
# 30003  David Guetta;Bebe Rexha  128.040
# 20008  David Guetta;Bebe Rexha  128.040
# 81210  David Guetta;Bebe Rexha  128.040
# ...

# %%
print(f"Average temp of top ten: {most_popular_ten["tempo"].mean()}")
# Out:
# Average temp of top ten: 127.4315

# %%
sns.histplot(spotify_df["valence"])
plt.show()

# %%
highest_loudness=spotify_df.loc[spotify_df["loudness"].idxmax(),["track_name"]]
highest_loudness
# Out:
# track_name    Fate Dance
# Name: 17574, dtype: object

# %%
lowest_loudness=spotify_df.loc[spotify_df["loudness"].idxmin(),["track_name"]]
lowest_loudness
# Out:
# track_name    Soothing White Noise - Loopable With No Fade
# Name: 101888, dtype: object

# %%
spotify_df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
danceability_genre=spotify_df.groupby("track_genre")["danceability"].mean()
danceability_genre
# Out:
# track_genre
# acoustic       0.549593
# afrobeat       0.669580
# alt-rock       0.534493
# alternative    0.559927
# ambient        0.367867
#                  ...
# techno         0.684348
# trance         0.583409
# trip-hop       0.634695
# turkish        0.616077
# world-music    0.414572
# Name: danceability, Length: 114, dtype: float64

# %%
instrumental_genres=spotify_df[spotify_df["instrumentalness"]>0.8]
instrumental_genres[["artists","track_name","track_genre","instrumentalness"]]
# Out:
#                          artists                                   track_name  \
# 62                   Kurt Cobain                               And I Love Her
# 163             Joseph Sullinger                                      Chi Mai
# 173     Agustín Amigó;Nylonwings                            Mujer con Abanico
# 315                   Andrew Foy                                Love Nwantiti
# 324              John Frusciante                                     Ramparts
# ...                          ...                                          ...
# 113979       Fondo de la lectura  Concentración: Sonidos de la Lluvia, Pt. 01
# 113986             Dulces Sueños                               Sueños Vividos
# 113990            Lucas Cervetti            Frecuencia Álmica XI - Solo Piano
# 113995             Rainy Lullaby                          Sleep My Little Boy
# 113996             Rainy Lullaby                             Water Into Light
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=spotify_df,x="explicit",y="popularity")
plt.show()

# %%
spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
numerical_features=["popularity","duration_min","danceability","energy","loudness","speechiness","acousticness","instrumentalness","liveness","valence","tempo"]
corr_features=spotify_df[numerical_features].corr()

# %%
corr_features
# Out:
#                   popularity  duration_min  danceability    energy  loudness  \
# popularity          1.000000     -0.007101      0.035448  0.001056  0.050423
# duration_min       -0.007101      1.000000     -0.073426  0.058523 -0.003470
# danceability        0.035448     -0.073426      1.000000  0.134325  0.259077
# energy              0.001056      0.058523      0.134325  1.000000  0.761690
# loudness            0.050423     -0.003470      0.259077  0.761690  1.000000
# speechiness        -0.044927     -0.062600      0.108626  0.142509  0.060826
# acousticness       -0.025472     -0.103788     -0.171533 -0.733906 -0.589803
# instrumentalness   -0.095139      0.124371     -0.185606 -0.181879 -0.433477
# liveness           -0.005387      0.010321     -0.131617  0.184796  0.076899
# valence            -0.040534     -0.154479      0.477341  0.258934  0.279848
# tempo               0.013205      0.024346     -0.050450  0.247851  0.212446
#
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corr_features,cmap="coolwarm",annot=True)
plt.show()

# %%
feel_good_songs=spotify_df[(spotify_df["danceability"]>0.70) & (spotify_df["energy"]>0.70) & (spotify_df["valence"]>0.70)]
feel_good_songs
# Out:
#         Unnamed: 0                track_id                  artists  \
# 365            365  3XdStlaHnq3JrmQDCRqEET  Yosui Inoue;Tamio Okuda
# 593            593  0pfG8LwO7hSdHe6hTgc6a6          Eric Hutchinson
# 663            663  12qmPGMrOCogibc7qyxT9s              Gen Hoshino
# 679            679  0qAMjeQFyd1qD0LDiV8gWp              KT Tunstall
# 691            691  6i1wlqIigKZTvMk0LTh5Id           Marc Broussard
# ...            ...                     ...                      ...
# 112835      112835  2pL9RRcyNIZU2wBWoPRmp2                    Hidra
# 112838      112838  4xfNO1hq6afGwhxvLMAkmy             Joker;Allame
# 112839      112839  3PPpiTKqKvRyFh0xFslZPS                     No.1
# 112941      112941  3vKjGeZez4Ge6VPyHc3bSK              Ajda Pekkan
# 113696      113696  797ikuM3k4gkjaxStQnxgW  Cesária Evora;Ismaël Lô
#
#                                   album_name  \
# 365                                   ショッピング
# 593                         Sounds Like This
# ...

# %%
feel_good_songs[["album_name","track_name","artists"]]
# Out:
#                                   album_name  \
# 365                                   ショッピング
# 593                         Sounds Like This
# 663     I Wanna Be Your Ghost (feat. Ghosts)
# 679                     Eye To The Telescope
# 691                                 Carencro
# ...                                      ...
# 112835                              Yenilmez
# 112838                            Featurings
# 112839                                 P.I.V
# 112941                     Farkın Bu Remixes
# 113696                               Rogamar
#
#                                   track_name                  artists
# 365                                   アジアの純真  Yosui Inoue;Tamio Okuda
# 593                        Outside Villanova          Eric Hutchinson
# 663     I Wanna Be Your Ghost (feat. Ghosts)              Gen Hoshino
# 679          Black Horse And The Cherry Tree              KT Tunstall
# ...
