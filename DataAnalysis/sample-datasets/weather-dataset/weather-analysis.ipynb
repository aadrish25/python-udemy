# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
weather_df=pd.read_csv("weatherHistory.csv")
weather_df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
weather_df["Formatted Date"]=pd.to_datetime(weather_df["Formatted Date"],utc=True)
weather_df
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 96448 2016-09-09 17:00:00+00:00  Partly Cloudy        rain        26.016667
# 96449 2016-09-09 18:00:00+00:00  Partly Cloudy        rain        24.583333
# 96450 2016-09-09 19:00:00+00:00  Partly Cloudy        rain        22.038889
# 96451 2016-09-09 20:00:00+00:00  Partly Cloudy        rain        21.522222
# 96452 2016-09-09 21:00:00+00:00  Partly Cloudy        rain        20.438889
#
# ...

# %%
print(f"Max date mentioned: {weather_df["Formatted Date"].dt.date.max()}")
print(f"Min date mentioned: {weather_df["Formatted Date"].dt.date.min()}")
# Out:
# Max date mentioned: 2016-12-31
# Min date mentioned: 2005-12-31

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  datetime64[ns, UTC]
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(8), object(3)
# memory usage: 8.8+ MB

# %%
weather_df.loc[weather_df["Temperature (C)"].idxmax(),["Temperature (C)","Formatted Date"]]
# Out:
# Temperature (C)                    39.905556
# Formatted Date     2007-07-22 13:00:00+00:00
# Name: 12759, dtype: object

# %%
sns.histplot(data=weather_df,x="Temperature (C)",kde=True)
plt.show()

# %%
sns.scatterplot(data=weather_df.head(100),x="Temperature (C)",y="Apparent Temperature (C)")
plt.show()

# %%
weather_df
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 96448 2016-09-09 17:00:00+00:00  Partly Cloudy        rain        26.016667
# 96449 2016-09-09 18:00:00+00:00  Partly Cloudy        rain        24.583333
# 96450 2016-09-09 19:00:00+00:00  Partly Cloudy        rain        22.038889
# 96451 2016-09-09 20:00:00+00:00  Partly Cloudy        rain        21.522222
# 96452 2016-09-09 21:00:00+00:00  Partly Cloudy        rain        20.438889
#
# ...

# %%
precip_type=weather_df.groupby("Precip Type")[["Humidity","Wind Speed (km/h)"]].mean()
precip_type
# Out:
#              Humidity  Wind Speed (km/h)
# Precip Type
# rain         0.718699          10.971219
# snow         0.863263           9.481998

# %%
weather_df["Formatted Date"] = pd.to_datetime(weather_df["Formatted Date"])

weather_df["Time of Day"]=weather_df["Formatted Date"].dt.time
weather_df
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 96448 2016-09-09 17:00:00+00:00  Partly Cloudy        rain        26.016667
# 96449 2016-09-09 18:00:00+00:00  Partly Cloudy        rain        24.583333
# 96450 2016-09-09 19:00:00+00:00  Partly Cloudy        rain        22.038889
# 96451 2016-09-09 20:00:00+00:00  Partly Cloudy        rain        21.522222
# 96452 2016-09-09 21:00:00+00:00  Partly Cloudy        rain        20.438889
#
# ...

# %%
sns.lineplot(x=weather_df["Formatted Date"],y=weather_df["Temperature (C)"])
plt.show()

# %%
temp_humid_corr=weather_df[["Temperature (C)","Humidity"]].corr()
temp_humid_corr
# Out:
#                  Temperature (C)  Humidity
# Temperature (C)         1.000000 -0.632255
# Humidity               -0.632255  1.000000

# %%
sns.scatterplot(data=weather_df.head(100),x="Temperature (C)",y="Humidity")
plt.show()

# %%
weather_df.value_counts("Wind Bearing (degrees)")
# Out:
# Wind Bearing (degrees)
# 0.0      2264
# 150.0    1799
# 160.0    1631
# 140.0    1509
# 310.0    1452
#          ...
# 65.0       52
# 83.0       48
# 95.0       48
# 86.0       47
# 94.0       44
# Name: count, Length: 360, dtype: int64

# %%
highest_windspeed=weather_df[["Wind Speed (km/h)","Formatted Date","Temperature (C)"]].sort_values(by="Wind Speed (km/h)",ascending=False).head(10)
highest_windspeed
# Out:
#        Wind Speed (km/h)            Formatted Date  Temperature (C)
# 12181            63.8526 2007-01-29 12:00:00+00:00         8.944444
# 20927            55.9314 2008-01-27 22:00:00+00:00         7.772222
# 75398            54.8849 2014-03-15 16:00:00+00:00        13.783333
# 12182            53.5969 2007-01-29 13:00:00+00:00         8.838889
# 12179            53.2427 2007-01-29 10:00:00+00:00         8.816667
# 20928            53.1944 2008-01-27 23:00:00+00:00         6.683333
# 12180            53.1944 2007-01-29 11:00:00+00:00         8.861111
# 12183            52.9368 2007-01-29 14:00:00+00:00         7.777778
# 75438            51.1497 2014-03-17 08:00:00+00:00        15.994444
# 20915            50.9726 2008-01-27 10:00:00+00:00         7.172222

# %%
visibility_snow=weather_df.groupby("Precip Type")["Visibility (km)"].mean()
visibility_snow
# Out:
# Precip Type
# rain    10.830711
# snow     6.636570
# Name: Visibility (km), dtype: float64

# %%
weather_df
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 96448 2016-09-09 17:00:00+00:00  Partly Cloudy        rain        26.016667
# 96449 2016-09-09 18:00:00+00:00  Partly Cloudy        rain        24.583333
# 96450 2016-09-09 19:00:00+00:00  Partly Cloudy        rain        22.038889
# 96451 2016-09-09 20:00:00+00:00  Partly Cloudy        rain        21.522222
# 96452 2016-09-09 21:00:00+00:00  Partly Cloudy        rain        20.438889
#
# ...

# %%
weather_df["Formatted Date"]=pd.to_datetime(weather_df["Formatted Date"])

# %%
weather_df
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 96448 2016-09-09 17:00:00+00:00  Partly Cloudy        rain        26.016667
# 96449 2016-09-09 18:00:00+00:00  Partly Cloudy        rain        24.583333
# 96450 2016-09-09 19:00:00+00:00  Partly Cloudy        rain        22.038889
# 96451 2016-09-09 20:00:00+00:00  Partly Cloudy        rain        21.522222
# 96452 2016-09-09 21:00:00+00:00  Partly Cloudy        rain        20.438889
#
# ...

# %%
weather_df["Pressure (millibars)"].dtype
# Out:
# dtype('float64')

# %%
weather_df["Pressure (millibars)"] = pd.to_numeric(weather_df["Pressure (millibars)"], errors="coerce")

# %%
weather_df["Time of Day"].dtype
# Out:
# dtype('<M8[ns]')

# %%
weather_df["Time of Day"]=pd.to_datetime(weather_df["Time of Day"])

# %%
sns.lineplot(data=weather_df,x="Time of Day",y="Pressure (millibars)")
plt.show()

# %%
weather_df
# Out:
#                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 96448 2016-09-09 17:00:00+00:00  Partly Cloudy        rain        26.016667
# 96449 2016-09-09 18:00:00+00:00  Partly Cloudy        rain        24.583333
# 96450 2016-09-09 19:00:00+00:00  Partly Cloudy        rain        22.038889
# 96451 2016-09-09 20:00:00+00:00  Partly Cloudy        rain        21.522222
# 96452 2016-09-09 21:00:00+00:00  Partly Cloudy        rain        20.438889
#
# ...

# %%
humidity_var=weather_df.groupby("Daily Summary")["Humidity"].mean()
humidity_var
# Out:
# Daily Summary
# Breezy and foggy starting in the evening.          0.979583
# Breezy and foggy until morning.                    0.803750
# Breezy and mostly cloudy overnight.                0.733750
# Breezy and partly cloudy in the afternoon.         0.418333
# Breezy in the morning and foggy in the evening.    0.802083
#                                                      ...
# Partly cloudy until night.                         0.650827
# Rain throughout the day.                           0.892917
# Rain until afternoon.                              0.868333
# Rain until morning.                                0.797083
# Windy in the afternoon.                            0.722917
# Name: Humidity, Length: 214, dtype: float64
