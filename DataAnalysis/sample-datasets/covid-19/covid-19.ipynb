# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
covid_data=pd.read_csv("covid-19.csv")
covid_data
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
covid_data.loc[covid_data["Confirmed"].idxmax(),["Country/Region","Confirmed"]]
# Out:
# Country/Region         US
# Confirmed         4290259
# Name: 173, dtype: object

# %%
avg_deaths=covid_data["Deaths"].mean()
print(f"Average deaths across all countries: {int(avg_deaths)}")
# Out:
# Average deaths across all countries: 3497

# %%
recovery_rate=covid_data[["Country/Region","Recovered / 100 Cases"]].sort_values(by="Recovered / 100 Cases",ascending=False)
recovery_rate.head(5)
# Out:
#    Country/Region  Recovered / 100 Cases
# 49       Dominica                 100.00
# 75       Holy See                 100.00
# 69        Grenada                 100.00
# 48       Djibouti                  98.38
# 78        Iceland                  98.33

# %%
covid_data.loc[covid_data["Confirmed"].idxmax(),["WHO Region"]]
# Out:
# WHO Region    Americas
# Name: 173, dtype: object

# %%
active_cases=covid_data[["Country/Region","Active"]].sort_values(by="Active",ascending=False)
active_cases.head(5)
# Out:
#      Country/Region   Active
# 173              US  2816444
# 23           Brazil   508116
# 79            India   495499
# 177  United Kingdom   254427
# 138          Russia   201097

# %%
covid_data
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
highest_weekly_percentage=covid_data.loc[covid_data["1 week % increase"].idxmax(),["Country/Region"]]
print(highest_weekly_percentage)
# Out:
# Country/Region    Papua New Guinea
# Name: 130, dtype: object

# %%
countries_high_new_cases=covid_data[covid_data["New cases"]>1000]
countries_high_new_cases[["Country/Region","New cases"]]
# Out:
#          Country/Region  New cases
# 6             Argentina       4890
# 13           Bangladesh       2772
# 20              Bolivia       1752
# 23               Brazil      23284
# 35                Chile       2133
# 37             Colombia      16306
# 50   Dominican Republic       1248
# 61               France       2551
# 79                India      44457
# 80            Indonesia       1525
# 81                 Iran       2434
# 82                 Iraq       2553
# 84               Israel       2029
# 89           Kazakhstan       1526
# 111              Mexico       4973
# 127                Oman       1053
# 128            Pakistan       1176
# 129              Panama       1146
# 132                Peru      13756
# 133         Philippines       1592
# 137             Romania       1104
# 138              Russia       5607
# 145        Saudi Arabia       1993
# 154        South Africa       7096
# 173                  US      56336

# %%
death_rate=covid_data[["Country/Region","Deaths / 100 Cases"]]
death_rate
# Out:
#          Country/Region  Deaths / 100 Cases
# 0           Afghanistan                3.50
# 1               Albania                2.95
# 2               Algeria                4.16
# 3               Andorra                5.73
# 4                Angola                4.32
# ..                  ...                 ...
# 182  West Bank and Gaza                0.73
# 183      Western Sahara               10.00
# 184               Yemen               28.56
# 185              Zambia                3.08
# 186            Zimbabwe                1.33
#
# [187 rows x 2 columns]

# %%
sns.histplot(data=death_rate,x="Deaths / 100 Cases")
plt.show()

# %%
features=["Confirmed","Deaths","Recovered"]
correl=covid_data[features].corr()
correl
# Out:
#            Confirmed    Deaths  Recovered
# Confirmed   1.000000  0.934698   0.906377
# Deaths      0.934698  1.000000   0.832098
# Recovered   0.906377  0.832098   1.000000

# %%
sns.scatterplot(data=covid_data,x="Confirmed",y="Recovered")
plt.show()

# %%
countries_no_recovery=covid_data.loc[covid_data["New recovered"]==0,["Country/Region","New recovered"]]
countries_no_recovery
# Out:
#           Country/Region  New recovered
# 3                Andorra              0
# 4                 Angola              0
# 11               Bahamas              0
# 14              Barbados              0
# 17                Belize              0
# ..                   ...            ...
# 168          Timor-Leste              0
# 170  Trinidad and Tobago              0
# 181              Vietnam              0
# 182   West Bank and Gaza              0
# 183       Western Sahara              0
#
# [61 rows x 2 columns]

# %%
avg_active_by_region=covid_data.groupby("WHO Region")["Active"].mean()
avg_active_by_region
# Out:
# WHO Region
# Africa                     5632.062500
# Americas                 115083.942857
# Eastern Mediterranean     11409.318182
# Europe                    19547.428571
# South-East Asia           63701.500000
# Western Pacific            4838.062500
# Name: Active, dtype: float64

# %%
countries_high_weeklyrise=covid_data.loc[covid_data["1 week % increase"]>20,["Country/Region","1 week % increase"]]
countries_high_weeklyrise
# Out:
#              Country/Region  1 week % increase
# 4                    Angola              26.84
# 6                 Argentina              28.02
# 8                 Australia              23.13
# 11                  Bahamas             119.54
# 21   Bosnia and Herzegovina              23.81
# 22                 Botswana              41.57
# 30                 Cambodia              32.16
# 37                 Colombia              26.03
# 41               Costa Rica              37.34
# 53              El Salvador              23.17
# 57                 Eswatini              26.83
# 58                 Ethiopia              42.52
# 63                   Gambia             191.07
# 79                    India              28.11
# 84                   Israel              23.04
# 87                    Japan              21.15
# 90                    Kenya              30.53
# 91                   Kosovo              26.14
# 93               Kyrgyzstan              22.67
# ...

# %%
weekly_increase_regionwise=covid_data.groupby("WHO Region")["1 week % increase"].mean().reset_index(name="Weekly increase %")
weekly_increase_regionwise
# Out:
#               WHO Region  Weekly increase %
# 0                 Africa          18.086458
# 1               Americas          16.331143
# 2  Eastern Mediterranean          10.482273
# 3                 Europe           7.769643
# 4        South-East Asia           8.513000
# 5        Western Pacific          22.111250

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=weekly_increase_regionwise,x="WHO Region",y="Weekly increase %")
plt.show()

# %%
covid_data["Fatality Rate"]=(covid_data["Deaths"]/covid_data["Confirmed"])*100
covid_data
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
highest_fatality_rates=covid_data[["Country/Region","WHO Region","Fatality Rate"]].sort_values(by="Fatality Rate",ascending=False)
highest_fatality_rates
# Out:
#                        Country/Region             WHO Region  Fatality Rate
# 184                             Yemen  Eastern Mediterranean      28.562980
# 177                    United Kingdom                 Europe      15.194824
# 16                            Belgium                 Europe      14.785934
# 85                              Italy                 Europe      14.256596
# 61                             France                 Europe      13.710790
# ..                                ...                    ...            ...
# 141                       Saint Lucia               Americas       0.000000
# 130                  Papua New Guinea        Western Pacific       0.000000
# 142  Saint Vincent and the Grenadines               Americas       0.000000
# 168                       Timor-Leste        South-East Asia       0.000000
# 181                           Vietnam        Western Pacific       0.000000
#
# [187 rows x 3 columns]
