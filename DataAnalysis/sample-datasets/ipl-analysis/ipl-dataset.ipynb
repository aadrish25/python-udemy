# %%
import pandas as pd

# %%
ipl_data=pd.read_csv("ipl_2013.csv")
ipl_data.head(10)
# Out:
#    Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1    Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2   Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3    Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4      Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5   Badrinath, S    2     IND   CSK      Batsman      63       0
# 5       6     Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6       7      Balaji, L    2     IND  CSK+       Bowler      51      27
# 7       8  Bollinger, DE    2     AUS   CSK       Bowler      54      50
# 8       9       Botha, J    2      SA    RR   Allrounder      83      17
# 9      10    Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# ...

# %%
column_list=ipl_data.columns
print(column_list)
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
ipl_data.transpose().head(10)
# Out:
#                       0             1            2          3             4    \
# Sl.NO.                  1             2            3          4             5
# PLAYER NAME   Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# AGE                     2             2            2          1             2
# COUNTRY                SA           BAN          IND        IND           IND
# TEAM                 KXIP           RCB          KKR        CSK           CSK
# PLAYING ROLE   Allrounder        Bowler       Bowler     Bowler       Batsman
# T-RUNS                  0           214          571        284            63
# T-WKTS                  0            18           58         31             0
# ODI-RUNS-S              0           657         1269        241            79
# ODI-SR-B              0.0         71.41        80.62      84.56         45.93
#
#                      5          6              7           8            9    \
# ...

# %%
print(ipl_data[0:5])
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
print(ipl_data[-5:])
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 125           0      0.00  ...  125.64       2       0     0    0.00  0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00  0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43  7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50  9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
print(ipl_data[["PLAYER NAME","COUNTRY","TEAM"]][-5:])
# Out:
#       PLAYER NAME COUNTRY   TEAM
# 125     Yadav, AS     IND     DC
# 126   Younis Khan     PAK     RR
# 127  Yuvraj Singh     IND  KXIP+
# 128   Zaheer Khan     IND    MI+
# 129    Zoysa, DNT      SL     DC

# %%
print(ipl_data.iloc[4:9,1:4])
# Out:
#      PLAYER NAME  AGE COUNTRY
# 4   Badrinath, S    2     IND
# 5     Bailey, GJ    2     AUS
# 6      Balaji, L    2     IND
# 7  Bollinger, DE    2     AUS
# 8       Botha, J    2      SA

# %%
print(ipl_data.value_counts("COUNTRY",normalize=True)*100)
# Out:
# COUNTRY
# IND    40.769231
# AUS    16.923077
# SA     12.307692
# SL      9.230769
# PAK     6.923077
# NZ      5.384615
# WI      4.615385
# ENG     2.307692
# BAN     0.769231
# ZIM     0.769231
# Name: proportion, dtype: float64

# %%
ipl_data
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
age_playingrole=pd.crosstab(ipl_data["AGE"],ipl_data["PLAYING ROLE"])
print(age_playingrole)
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# AGE
# 1                      4        5       7          0
# 2                     25       21      29         11
# 3                      6       13       8          1

# %%
df1=ipl_data[["PLAYER NAME","SOLD PRICE"]]
print(df1)
df1.sort_values(axis=0,by="SOLD PRICE",inplace=True)
print(df1)
# Out:
#       PLAYER NAME  SOLD PRICE
# 0     Abdulla, YA       50000
# 1    Abdur Razzak       50000
# 2     Agarkar, AB      350000
# 3       Ashwin, R      850000
# 4    Badrinath, S      800000
# ..            ...         ...
# 125     Yadav, AS      750000
# 126   Younis Khan      225000
# 127  Yuvraj Singh     1800000
# 128   Zaheer Khan      450000
# 129    Zoysa, DNT      110000
#
# [130 rows x 2 columns]
#        PLAYER NAME  SOLD PRICE
# 73      Noffke, AA       20000
# 46     Kamran Khan       24000
# 5       Bailey, GJ       50000
# 0      Abdulla, YA       50000
# 34   Henriques, MC       50000
# ..             ...         ...
# 113     Tiwary, SS     1600000
# 50        Kohli, V     1800000
# 93       Sehwag, V     1800000
# 127   Yuvraj Singh     1800000
# 111  Tendulkar, SR     1800000
#
# [130 rows x 2 columns]
# C:\Users\User\AppData\Local\Temp\ipykernel_15380\1735274126.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
ipl_data["PREMIUM"]=ipl_data["SOLD PRICE"]-ipl_data["BASE PRICE"]
ipl_data
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
max_premium_players=ipl_data[["PLAYER NAME","COUNTRY","PREMIUM"]]
max_premium_players.sort_values("PREMIUM",inplace=True,ascending=False)
max_premium_players
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15380\802750965.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   max_premium_players.sort_values("PREMIUM",inplace=True,ascending=False)
#        PLAYER NAME COUNTRY  PREMIUM
# 50        Kohli, V     IND  1650000
# 113     Tiwary, SS     IND  1500000
# 127   Yuvraj Singh     IND  1400000
# 111  Tendulkar, SR     IND  1400000
# 93       Sehwag, V     IND  1400000
# ..             ...     ...      ...
# 115       Umar Gul     PAK        0
# 118  Van der Merwe      SA        0
# 117    Vaas, WPUJC      SL        0
# 122      Warne, SK     AUS        0
# 126    Younis Khan     PAK        0
#
# [130 rows x 3 columns]

# %%
average_sold_per_age=ipl_data.groupby("AGE")["SOLD PRICE"].mean()
average_sold_per_age=average_sold_per_age.reset_index()

# %%
average_sp_per_age_playingrole=ipl_data.groupby(["AGE","PLAYING ROLE"])["SOLD PRICE"].mean()
average_sp_per_age_playingrole=average_sp_per_age_playingrole.reset_index()

# %%
average_sold_per_age
# Out:
#    AGE     SOLD PRICE
# 0    1  720250.000000
# 1    2  484534.883721
# 2    3  520178.571429

# %%
average_sp_per_age_playingrole
# Out:
#     AGE PLAYING ROLE    SOLD PRICE
# 0     1   Allrounder  5.875000e+05
# 1     1      Batsman  1.110000e+06
# 2     1       Bowler  5.177143e+05
# 3     2   Allrounder  4.494000e+05
# 4     2      Batsman  6.547619e+05
# 5     2       Bowler  3.979310e+05
# 6     2    W. Keeper  4.677273e+05
# 7     3   Allrounder  7.666667e+05
# 8     3      Batsman  4.576923e+05
# 9     3       Bowler  4.143750e+05
# 10    3    W. Keeper  7.000000e+05

# %%
soldprice_comparison=pd.merge(left=average_sold_per_age,right=average_sp_per_age_playingrole,on="AGE",how="outer")
soldprice_comparison
# Out:
#     AGE   SOLD PRICE_x PLAYING ROLE  SOLD PRICE_y
# 0     1  720250.000000   Allrounder  5.875000e+05
# 1     1  720250.000000      Batsman  1.110000e+06
# 2     1  720250.000000       Bowler  5.177143e+05
# 3     2  484534.883721   Allrounder  4.494000e+05
# 4     2  484534.883721      Batsman  6.547619e+05
# 5     2  484534.883721       Bowler  3.979310e+05
# 6     2  484534.883721    W. Keeper  4.677273e+05
# 7     3  520178.571429   Allrounder  7.666667e+05
# 8     3  520178.571429      Batsman  4.576923e+05
# 9     3  520178.571429       Bowler  4.143750e+05
# 10    3  520178.571429    W. Keeper  7.000000e+05

# %%
soldprice_comparison.rename(columns={"SOLD PRICE_x":"SOLD PRICE FOR AGE","SOLD PRICE_y":"SOLD PRICE FOR PLAYING ROLE"},inplace=True)
soldprice_comparison
# Out:
#     AGE  SOLD PRICE FOR AGE PLAYING ROLE  SOLD PRICE FOR PLAYING ROLE
# 0     1       720250.000000   Allrounder                 5.875000e+05
# 1     1       720250.000000      Batsman                 1.110000e+06
# 2     1       720250.000000       Bowler                 5.177143e+05
# 3     2       484534.883721   Allrounder                 4.494000e+05
# 4     2       484534.883721      Batsman                 6.547619e+05
# 5     2       484534.883721       Bowler                 3.979310e+05
# 6     2       484534.883721    W. Keeper                 4.677273e+05
# 7     3       520178.571429   Allrounder                 7.666667e+05
# 8     3       520178.571429      Batsman                 4.576923e+05
# 9     3       520178.571429       Bowler                 4.143750e+05
# 10    3       520178.571429    W. Keeper                 7.000000e+05

# %%
soldprice_comparison["CHANGE"]=soldprice_comparison.apply(lambda x: (x["SOLD PRICE FOR AGE"]-x["SOLD PRICE FOR PLAYING ROLE"])/x["SOLD PRICE FOR AGE"],axis=1)
soldprice_comparison
# Out:
#     AGE  SOLD PRICE FOR AGE PLAYING ROLE  SOLD PRICE FOR PLAYING ROLE  \
# 0     1       720250.000000   Allrounder                 5.875000e+05
# 1     1       720250.000000      Batsman                 1.110000e+06
# 2     1       720250.000000       Bowler                 5.177143e+05
# 3     2       484534.883721   Allrounder                 4.494000e+05
# 4     2       484534.883721      Batsman                 6.547619e+05
# 5     2       484534.883721       Bowler                 3.979310e+05
# 6     2       484534.883721    W. Keeper                 4.677273e+05
# 7     3       520178.571429   Allrounder                 7.666667e+05
# 8     3       520178.571429      Batsman                 4.576923e+05
# 9     3       520178.571429       Bowler                 4.143750e+05
# 10    3       520178.571429    W. Keeper                 7.000000e+05
#
#       CHANGE
# 0   0.184311
# 1  -0.541132
# 2   0.281202
# 3   0.072513
# 4  -0.351320
# 5   0.178736
# 6   0.034688
# ...

# %%
ipl_data
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
ipl_data["SIXERS"]>80
highest_sixers=ipl_data[ipl_data["SIXERS"]>80]
highest_sixers[["PLAYER NAME","SIXERS"]]
# Out:
#       PLAYER NAME  SIXERS
# 26      Gayle, CH     129
# 28  Gilchrist, AC      86
# 82     Pathan, YK      81
# 88      Raina, SK      97
# 97     Sharma, RG      82

# %%
ipl_data.drop("Sl.NO.",axis=1)
# Out:
#       PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0     Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1    Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2     Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3       Ashwin, R    1     IND    CSK       Bowler     284      31
# 4    Badrinath, S    2     IND    CSK      Batsman      63       0
# ..            ...  ...     ...    ...          ...     ...     ...
# 125     Yadav, AS    2     IND     DC      Batsman       0       0
# 126   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ...  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0             0      0.00         0  ...       0     307    15   20.47   8.90
# ...

# %%
ipl_data.isna().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 125    False
# 126    False
# 127    False
# 128    False
# 129    False
# Length: 130, dtype: bool

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

sns.barplot(data=average_sold_per_age,x="AGE",y="SOLD PRICE")
plt.show()

# %%
sns.barplot(data=average_sp_per_age_playingrole,x="PLAYING ROLE",y="SOLD PRICE",hue="AGE",palette="Set2")
plt.show()

# %%
ipl_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
sns.histplot(data=ipl_data,x="SOLD PRICE",kde=True)
plt.show()

# %%
sns.kdeplot(data=ipl_data,x="SOLD PRICE",fill=False)
plt.show()

# %%
plt.hist(data=ipl_data,x="SOLD PRICE",edgecolor="Black",bins=20)
plt.show()

# %%
box=sns.boxplot(data=ipl_data,x="SOLD PRICE")
plt.show()

# %%
print(ipl_data[["CAPTAINCY EXP","SOLD PRICE"]])
# Out:
#      CAPTAINCY EXP  SOLD PRICE
# 0                0       50000
# 1                0       50000
# 2                0      350000
# 3                0      850000
# 4                0      800000
# ..             ...         ...
# 125              0      750000
# 126              1      225000
# 127              1     1800000
# 128              0      450000
# 129              0      110000
#
# [130 rows x 2 columns]

# %%
print(ipl_data[ipl_data["CAPTAINCY EXP"]==1])
# Out:
#      Sl.NO.        PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  \
# 5         6         Bailey, GJ    2     AUS    CSK      Batsman       0
# 8         9           Botha, J    2      SA     RR   Allrounder      83
# 9        10        Boucher, MV    2      SA   RCB+    W. Keeper    5515
# 11       12     Chanderpaul, S    3      WI    RCB      Batsman    9918
# 13       14    de Villiers, AB    2      SA    DD+    W. Keeper    5457
# 15       16          Dhoni, MS    2     IND    CSK    W. Keeper    3509
# 16       17        Dilshan, TM    2      SL    DD+   Allrounder    4722
# 18       19         Dravid, RS    3     IND   RCB+      Batsman   13288
# 22       23        Fleming, SP    3      NZ    CSK      Batsman    7172
# 23       24        Flintoff, A    2     ENG    CSK   Allrounder    3845
# 24       25         Gambhir, G    2     IND    DD+      Batsman    3712
# 25       26        Ganguly, SC    3     IND   KKR+      Batsman    7212
# ...

# %%
players_with_cap_ex=ipl_data[ipl_data["CAPTAINCY EXP"]==1]
players_without_cap_ex=ipl_data[ipl_data["CAPTAINCY EXP"]==0]
sns.displot(players_with_cap_ex["SOLD PRICE"])
sns.displot(players_without_cap_ex["SOLD PRICE"])
plt.show()

# %%
sns.boxplot(data=ipl_data,x="PLAYING ROLE",y="SOLD PRICE")
plt.show()

# %%
sns.scatterplot(data=ipl_data[ipl_data["PLAYING ROLE"]=="Batsman"],x="SIXERS",y="SOLD PRICE")
plt.show()

# %%
sns.regplot(data=ipl_data[ipl_data["PLAYING ROLE"]=="Batsman"],x="SIXERS",y="SOLD PRICE")
plt.show()

# %%
ipl_data
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
influential_features=["BASE PRICE","SOLD PRICE","ODI-RUNS-S","SIXERS"]
sns.pairplot(ipl_data[influential_features])
plt.show()

# %%
correlation_values=ipl_data[influential_features].corr()
correlation_values
# Out:
#             BASE PRICE  SOLD PRICE  ODI-RUNS-S    SIXERS
# BASE PRICE    1.000000    0.523510    0.388967  0.161889
# SOLD PRICE    0.523510    1.000000    0.337834  0.450609
# ODI-RUNS-S    0.388967    0.337834    1.000000  0.376012
# SIXERS        0.161889    0.450609    0.376012  1.000000

# %%
sns.heatmap(correlation_values,cmap="coolwarm",annot=True)
plt.show()
